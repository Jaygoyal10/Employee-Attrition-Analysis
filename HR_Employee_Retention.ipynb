# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("D:/JAI_ANALYTICS_NEW/Project_new/Employee_Attrition/hr_employee_retention.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                       1.0          80.0               0.0
# 1  ...                       4.0          80.0               1.0
# 2  ...                       2.0          80.0               0.0
# 3  ...                       3.0          80.0               0.0
# 4  ...                       4.0          80.0               1.0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                8.0                    0.0             1.0             6.0
# 1               10.0                    3.0             3.0            10.0
# 2                7.0                    3.0             3.0             0.0
# 3                8.0                    3.0             3.0             8.0
# 4                6.0                    3.0             3.0             2.0
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                4.0                      0.0                   5.0
# 1                7.0                      1.0                   7.0
# 2                0.0                      0.0                   0.0
# 3                7.0                      3.0                   0.0
# 4                2.0                      2.0                   2.0
#
# [5 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1469 entries, 0 to 1468
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1469 non-null   int64
#  1   Attrition                 1469 non-null   object
#  2   BusinessTravel            1469 non-null   object
#  3   DailyRate                 1469 non-null   int64
#  4   Department                1469 non-null   object
#  5   DistanceFromHome          1469 non-null   int64
#  6   Education                 1469 non-null   int64
#  7   EducationField            1469 non-null   object
#  8   EmployeeCount             1469 non-null   int64
#  9   EmployeeNumber            1469 non-null   int64
#  10  EnvironmentSatisfaction   1469 non-null   int64
#  11  Gender                    1469 non-null   object
#  12  HourlyRate                1469 non-null   int64
#  13  JobInvolvement            1469 non-null   int64
#  14  JobLevel                  1469 non-null   float64
#  15  JobRole                   1469 non-null   object
#  16  JobSatisfaction           1469 non-null   float64
#  17  MaritalStatus             1469 non-null   object
#  18  MonthlyIncome             1469 non-null   float64
#  19  MonthlyRate               1469 non-null   float64
#  20  NumCompaniesWorked        1469 non-null   float64
#  21  Over18                    1469 non-null   object
#  22  OverTime                  1469 non-null   object
#  23  PercentSalaryHike         1469 non-null   float64
#  24  PerformanceRating         1469 non-null   float64
#  25  RelationshipSatisfaction  1469 non-null   float64
#  26  StandardHours             1469 non-null   float64
#  27  StockOptionLevel          1469 non-null   float64
#  28  TotalWorkingYears         1469 non-null   float64
#  29  TrainingTimesLastYear     1469 non-null   float64
#  30  WorkLifeBalance           1469 non-null   float64
#  31  YearsAtCompany            1469 non-null   float64
#  32  YearsInCurrentRole        1469 non-null   float64
#  33  YearsSinceLastPromotion   1469 non-null   float64
#  34  YearsWithCurrManager      1469 non-null   float64
# dtypes: float64(17), int64(9), object(9)
# memory usage: 401.8+ KB

# %%
df.shape
# Out:
# (1469, 35)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.Attrition.value_counts()
# Out:
# Attrition
# No     1232
# Yes     237
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1469.000000  1469.000000       1469.000000  1469.000000         1469.0
# mean     36.925800   802.604493          9.193329     2.912866            1.0
# std       9.138166   403.620803          8.109565     1.024511            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1469.000000              1469.000000  1469.000000     1469.000000
# mean      1024.155208                 2.722260    65.880191        2.729067
# std        601.613207                 1.093292    20.332001        0.711031
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.000000                 2.000000    48.000000        2.000000
# 50%       1019.000000                 3.000000    66.000000        3.000000
# 75%       1555.000000                 4.000000    84.000000        3.000000
# max       2065.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1469.000000  ...               1469.000000         1469.0
# mean      2.063989  ...                  2.713410           80.0
# std       1.107316  ...                  1.080653            0.0
# min       1.000000  ...                  1.000000           80.0
# 25%       1.000000  ...                  2.000000           80.0
# 50%       2.000000  ...                  3.000000           80.0
# 75%       3.000000  ...                  4.000000           80.0
# max       5.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1469.000000        1469.000000            1469.000000
# mean           0.794418          11.283186               2.799183
# std            0.852115           7.782211               1.289699
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1469.000000     1469.000000         1469.000000
# mean          2.760381        7.010211            4.230088
# std           0.705976        6.128108            3.624229
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1469.000000           1469.000000
# mean                  2.188564              4.124575
# std                   3.223378              3.568921
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# ### **DISTRIBUTION OF EMPLOYEE ATTRITION IN THE COMPANY**

# %%
labels = 'Atrrition NO', 'Atrrition YES'
df['Attrition'].astype(str).value_counts().plot(kind = 'pie', figsize = (10,4), autopct = "%1.1f%%", startangle = 90, labels = None)
plt.title("Distribution of Employee Attrition in the company", y = 1.12)
plt.axis('equal')
plt.legend(labels=labels, loc = 'upper left')
plt.show()

# %% [markdown]
# ### From the piechart , we can see that out of **1470** employees , **16%** of the employees left their job due to some reasons whereas other **84%** of the employees preferred to continue their job at the company.

# %% [markdown]
# ## **Analysis Of The Feature Names**

# %% [markdown]
# ### **Removing Useless Features**

# %%
# Drop useless features - StandardHours, EmployeeCount, Over18, EmployeeNumber, StockOptionLevel

df.drop(columns = ['StandardHours', 'EmployeeCount', 'Over18', 'EmployeeNumber', 'StockOptionLevel'], inplace=True)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PercentSalaryHike  PerformanceRating  \
# 0  Female  ...               11.0                3.0
# 1    Male  ...               23.0                4.0
# 2    Male  ...               15.0                3.0
# 3  Female  ...               11.0                3.0
# 4    Male  ...               12.0                3.0
#
#    RelationshipSatisfaction TotalWorkingYears  TrainingTimesLastYear  \
# 0                       1.0               8.0                    0.0
# 1                       4.0              10.0                    3.0
# 2                       2.0               7.0                    3.0
# 3                       3.0               8.0                    3.0
# 4                       4.0               6.0                    3.0
#
#   WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0             1.0             6.0                 4.0
# 1             3.0            10.0                 7.0
# 2             3.0             0.0                 0.0
# 3             3.0             8.0                 7.0
# 4             3.0             2.0                 2.0
#
#    YearsSinceLastPromotion YearsWithCurrManager
# 0                      0.0                  5.0
# 1                      1.0                  7.0
# 2                      0.0                  0.0
# 3                      3.0                  0.0
# 4                      2.0                  2.0
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (1469, 30)

# %% [markdown]
# ### **Analysis of the Rating Features**
#
# ##### JobSatisfaction
# ##### EnvironmentSatisfaction
# ##### RelationshipSatisfaction
# ##### JobInvolvement
# ##### WorkLifeBalance
# ##### PerformanceRating

# %%
df['JobSatisfaction'].value_counts()
# Out:
# JobSatisfaction
# 4.0    459
# 3.0    441
# 1.0    289
# 2.0    280
# Name: count, dtype: int64

# %%
fig = plt.figure() 

ax1 = fig.add_subplot(221) 
ax2 = fig.add_subplot(222)  
ax3 = fig.add_subplot(223) 
ax4 = fig.add_subplot(224)  

labels = 'Low','Medium','High','Very High'

df['JobSatisfaction'].astype(str).value_counts().plot(kind='pie', figsize=(15, 6),autopct='%1.1f%%',startangle=90, labels=None, ax=ax1) # add to subplot 2
ax1.set_title ('Rating of Job Satisfaction by Employees')
fig.legend(labels=labels,loc='center')

df['EnvironmentSatisfaction'].astype(str).value_counts().plot(kind='pie',figsize=(15, 6), autopct='%1.1f%%', startangle=90, labels=None, ax=ax2) 
ax2.set_title('Rating of Environmental Satisfaction by Employees')

df['RelationshipSatisfaction'].astype(str).value_counts().plot(kind='pie', figsize=(15, 6), autopct='%1.1f%%', startangle=90, labels=None, ax=ax3)
ax3.set_title('Rating of Relationship Satisfaction by Employees')

df['JobInvolvement'].astype(str).value_counts().plot(kind='pie', figsize=(15, 6), autopct='%1.1f%%', startangle=90,  labels=None, ax=ax4) 
ax4.set_title('Rating of Job Involvement by Employees')

plt.show()

# %% [markdown]
# ### **From the subplot, we can see that more than 60% of the employees are :**
#
# ##### Not Satisfied in their Job
# ##### Not Satisfied with their Work Environmnet
# ##### Not Satisfied in their Relationship
# ##### Not Getting involved in their job

# %%
fig2 = plt.figure() 

ax5 = fig2.add_subplot(121) 
ax6 = fig2.add_subplot(122)  
  
labels_list1 = 'Bad','Good','Better','Best' 
labels_list2 = 'Low','Good','Excellent','Outstanding'

df['WorkLifeBalance'].astype(str).value_counts().plot(kind='pie', figsize=(10, 4), autopct='%1.1f%%', startangle=90, labels=None, ax=ax5) # add to subplot 2
ax5.set_title ('Rating of Work-Life Balance by Employees')
ax5.legend(labels=labels_list1,loc='upper right')

df['PerformanceRating'].astype(str).value_counts().plot(kind='pie', figsize=(10, 4), autopct='%1.1f%%', startangle=90, labels=None, ax=ax6) 
ax6.set_title('Performance Rating of the Employees')
ax6.legend(labels=labels_list2,loc='upper right')

plt.show()

# %% [markdown]
# ### **From the above piecharts, we can see that:**
#
# ##### Almost **60%** of the employees have rated their Work-life Balance as Bad
# ##### Almost **85%** of the employees have a low performance rating

# %% [markdown]
# # **Analysis of Business Travel Feature**

# %%
bta = df.groupby('BusinessTravel')['Attrition'].value_counts(normalize=False).unstack()

bta.plot(kind = 'bar', alpha = 1, stacked = 'False')
plt.title('Business Travel Vs Attrition')
plt.ylabel('Number of Employee')
plt.show()

# %% [markdown]
# #### From the above data it is clear that Employees who travel rarely have more attrition rate followed by Employees who travel frequently
#
# ##### Best way to reduce this attrition is to conduct monthly survey and to assign travel according to the Employees' business travel interest

# %% [markdown]
# # **Analysis of Work Experience**

# %% [markdown]
# #### YearsAtCompany
# #### YearsInCurrentRole
# #### YearsSinceLastPromotion
# #### YearsWithCurrManager
# #### TotalWorkingYears

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
we = df[['YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition']]
we.head()
# Out:
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0             6.0                 4.0                      0.0
# 1            10.0                 7.0                      1.0
# 2             0.0                 0.0                      0.0
# 3             8.0                 7.0                      3.0
# 4             2.0                 2.0                      2.0
#
#    YearsWithCurrManager Attrition
# 0                   5.0       Yes
# 1                   7.0        No
# 2                   0.0       Yes
# 3                   0.0        No
# 4                   2.0        No

# %%
yac = df.groupby("YearsAtCompany")['Attrition'].value_counts(normalize=False).unstack()

yac.plot(kind = 'bar', stacked = 'False', figsize = (10,6))
plt.title('Years at Company of Employee')
plt.ylabel('Number of Employee')
plt.show()

# %% [markdown]
# It is observed that freshers leave the company very likely so it's important that company creates a new policy to handle freshers so they don't leave the company from the start

# %% [markdown]
# # **Analysis of Monthly Income**

# %%
mi = df[df['Attrition'] == 'Yes']['MonthlyIncome']
mi = mi.reset_index()
mi.drop(['index'], axis = 1, inplace = True)

mn = df[df['Attrition'] == 'No']['MonthlyIncome']
mn = mn.reset_index()
mn.drop(['index'], axis = 1, inplace = True)

mi['mn'] = mn
mi.rename(columns = {'MonthlyIncome' : 'Yes', 'mn' : 'No'}, inplace = True)
mi.head()
# Out:
#       Yes      No
# 0  5993.0  5130.0
# 1  2090.0  2909.0
# 2  2028.0  3468.0
# 3  3407.0  3068.0
# 4  2960.0  2670.0

# %%
mi.plot(kind = 'box', figsize = (10,6))

plt.title("Box plot of Monthly Income Vs Attrition")
plt.ylabel("Monthly Income")
plt.show()

# %% [markdown]
# Employees who left their jobs tend to have low average monthly income than those who continued their job in the company

# %% [markdown]
# # **Over Time Employee Analysis**

# %%
ote = df[['OverTime', 'MonthlyIncome', 'Attrition']]
over_time_ana = ote[(df['OverTime']=='Yes') & (df['Attrition']=='Yes')]
over_time_ana = over_time_ana.sort_values(by = 'MonthlyIncome', ascending=False, axis=0) #sorting to get the top values
count, bin_edges = np.histogram(over_time_ana['MonthlyIncome'])

over_time_ana.plot(kind='hist', xticks=bin_edges)
plt.show()

# %%
over_time_ana_no = ote[(df['OverTime'] == 'Yes') & (df['Attrition'] == 'No')]
count, bin_edge = np.histogram(over_time_ana_no['MonthlyIncome'])

over_time_ana_no.plot(kind = 'hist', xticks = bin_edges)
plt.show()

# %%
onay = ote[(df['OverTime']=='No') & (df['Attrition']=='Yes')]
count, bin_edges = np.histogram(onay['MonthlyIncome'])

onay.plot(kind='hist', xticks=bin_edges)
plt.show()

# %%
onan = ote[(df['OverTime']=='No') & (df['Attrition']=='No')]
count, bin_edges = np.histogram(onan['MonthlyIncome'])

onan.plot(kind='hist',alpha =0.4, xticks=bin_edges)
plt.show()

# %% [markdown]
# # **Analysis on Department**

# %%
dept = df[['Department', 'Attrition']]
dept.head()
# Out:
#                Department Attrition
# 0                   Sales       Yes
# 1  Research & Development        No
# 2  Research & Development       Yes
# 3  Research & Development        No
# 4  Research & Development        No

# %%
dept['Department'].value_counts()
# Out:
# Department
# Research & Development    960
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
dept['Department'].value_counts().plot(kind='pie', figsize=(8, 5), autopct='%1.1f%%', startangle=90, labels=None)   
plt.axis('equal') 
plt.legend(labels=dept['Department'].unique(), loc='upper left') 
plt.show()

# %%
dpm = df.groupby("Department")['Attrition'].value_counts(normalize=False).unstack()
dpm = dpm.transpose()
dpm
# Out:
# Department  Human Resources  Research & Development  Sales
# Attrition
# No                       51                     827    354
# Yes                      12                     133     92

# %%
labels = ['Human Resources', 'Research & Development', 'Sales',]
sizes = [63, 765, 350]
labels_attrition = ['Yes','No','Yes','No','Yes','No']
sizes_attrition = [12,51,133,828,92,354]
colors = ['#ff6666', '#ffcc99', '#99ff99']

colors_attrition = ['#0a0e77','#9e0723', '#0a0e77','#9e0723', '#0a0e77','#9e0723', '#0a0e77','#9e0723']
 
# Plot
plt.pie(sizes, autopct='%1.1f%%', pctdistance=.87, labels=labels, colors=colors, startangle=90,frame=True)
plt.pie(sizes_attrition,colors=colors_attrition,radius=0.75,startangle=90)
centre_circle = plt.Circle((0,0),0.5,color='black', fc='white',linewidth=0.5)
fig6 = plt.gcf()
fig6.gca().add_artist(centre_circle)

#legend
import matplotlib.patches as mpatches
pur = mpatches.Patch(color='#0a0e77', label='Yes')
pin = mpatches.Patch(color='#9e0723', label='No')
plt.legend(handles=[pur, pin], loc='upper left')

plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Gender Analysis**

# %%
gda = df[['Gender', 'DistanceFromHome', 'Attrition']]
gda.head()
# Out:
#    Gender  DistanceFromHome Attrition
# 0  Female                 1       Yes
# 1    Male                 8        No
# 2    Male                 2       Yes
# 3  Female                 3        No
# 4    Male                 2        No

# %%
gda['Gender'].value_counts()
# Out:
# Gender
# Male      881
# Female    588
# Name: count, dtype: int64

# %%
gda['Gender'].value_counts().plot(kind='pie', figsize=(6, 4), autopct='%1.1f%%', startangle=90, labels=None)   
plt.axis('equal') 
plt.legend(labels=['Male', 'Female'], loc='upper left') 
plt.show()

# %%
fma = gda.groupby("Gender")['Attrition'].value_counts(normalize=False).unstack()
fma = fma.transpose()
fma
# Out:
# Gender     Female  Male
# Attrition
# No            501   731
# Yes            87   150

# %%
labels = ['Male', 'Female']
sizes = [882,588]
labels_attrition = ['Yes','No','Yes','No']
sizes_attrition = [150,732,87,501]
colors = ['#ff6666', '#ffcc99']

colors_attrition = ['#c2c2f0','#ffb3e6', '#c2c2f0','#ffb3e6']
 
# Plot
plt.pie(sizes, labels=labels, colors=colors, startangle=90,frame=True)
plt.pie(sizes_attrition,colors=colors_attrition,radius=0.75,startangle=90)
centre_circle = plt.Circle((0,0),0.5,color='black', fc='white',linewidth=0.5)
fig6 = plt.gcf()
fig6.gca().add_artist(centre_circle)

#legend
import matplotlib.patches as mpatches
pur = mpatches.Patch(color='#c2c2f0', label='Yes')
pin = mpatches.Patch(color='#ffb3e6', label='No')
plt.legend(handles=[pur, pin], loc='center')

plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Analysis of Marital Status**

# %%
ms = df[['MaritalStatus', 'Attrition']]
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PercentSalaryHike  PerformanceRating  \
# 0  Female  ...               11.0                3.0
# 1    Male  ...               23.0                4.0
# 2    Male  ...               15.0                3.0
# 3  Female  ...               11.0                3.0
# 4    Male  ...               12.0                3.0
#
#    RelationshipSatisfaction TotalWorkingYears  TrainingTimesLastYear  \
# 0                       1.0               8.0                    0.0
# 1                       4.0              10.0                    3.0
# 2                       2.0               7.0                    3.0
# 3                       3.0               8.0                    3.0
# 4                       4.0               6.0                    3.0
#
#   WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0             1.0             6.0                 4.0
# 1             3.0            10.0                 7.0
# 2             3.0             0.0                 0.0
# 3             3.0             8.0                 7.0
# 4             3.0             2.0                 2.0
#
#    YearsSinceLastPromotion YearsWithCurrManager
# 0                      0.0                  5.0
# 1                      1.0                  7.0
# 2                      0.0                  0.0
# 3                      3.0                  0.0
# 4                      2.0                  2.0
#
# [5 rows x 30 columns]

# %%
ms['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     672
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
ms['MaritalStatus'].value_counts().plot(kind='pie', figsize=(6, 4), autopct='%1.1f%%', startangle=90, labels=None)   
plt.axis('equal') 
plt.legend(labels=['Married', 'Single', 'Divorced'], loc='upper left') 
plt.show()
